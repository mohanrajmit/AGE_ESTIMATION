# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/AGE_ESTIMATION/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mohanrajmit/AGE_ESTIMATION.git
# Out:
# Cloning into 'AGE_ESTIMATION'...
# remote: Enumerating objects: 26090, done.
# remote: Counting objects: 100% (26090/26090), done.
# remote: Compressing objects: 100% (18686/18686), done.
# remote: Total 26090 (delta 7402), reused 26087 (delta 7402), pack-reused 0
# Receiving objects: 100% (26090/26090), 57.07 MiB | 25.80 MiB/s, done.
# Resolving deltas: 100% (7402/7402), done.
# Checking out files: 100% (26545/26545), done.

# %% [markdown]
# Age Estimation for Indian Movie Face Dataset

# %%
# keras imports

from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing import image
from keras.models import Model
from keras.models import model_from_json
from keras.layers import Input
from keras.applications.inception_resnet_v2 import InceptionResNetV2

# other imports
from sklearn.preprocessing import LabelEncoder
import numpy as np
import glob
import cv2
import h5py
import os
import json
import datetime
import time
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
data=pd.read_csv("AGE_ESTIMATION/dataset/train/train.csv")

image_name = data["ID"]
label_name = data["Class"]

features = []
labels = []

# %%
print(data.head())
# Out:
#           ID   Class
# 0    377.jpg  MIDDLE
# 1  17814.jpg   YOUNG
# 2  21283.jpg  MIDDLE
# 3  16496.jpg   YOUNG
# 4   4487.jpg  MIDDLE

# %%
base_model = Xception(weights="imagenet")
model = Model(input=base_model.input, output=base_model.get_layer('avg_pool').output)
image_size = (299, 299)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0712 07:00:25.639907 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0712 07:00:25.679094 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0712 07:00:25.688298 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0712 07:00:25.729638 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0712 07:00:25.730836 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0712 07:00:28.707235 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0712 07:00:29.190326 140450621196160 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91889664/91884032 [==============================] - 4s 0us/step
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("av...)`

# %%
dataset_path="AGE_ESTIMATION/dataset/train/"

# %%
for image_name1,label in zip(image_name,label_name):
	
	print("the image name  {} and label{}" .format(image_name1,label))
	image_path= str(dataset_path+image_name1)
	#print(image_path)
	#image =cv2.imread(image_path)
	#images.append(image)
	#labels.append(label)

	img = image.load_img(image_path, target_size=image_size)
	x = image.img_to_array(img)
	x = np.expand_dims(x, axis=0)
	x = preprocess_input(x)
	feature = model.predict(x)
	flat = feature.flatten()
	features.append(flat)
	labels.append(label)
# Out:
# the image name  377.jpg and labelMIDDLE
# the image name  17814.jpg and labelYOUNG
# the image name  21283.jpg and labelMIDDLE
# the image name  16496.jpg and labelYOUNG
# the image name  4487.jpg and labelMIDDLE
# the image name  6283.jpg and labelMIDDLE
# the image name  23495.jpg and labelYOUNG
# the image name  7100.jpg and labelYOUNG
# the image name  6028.jpg and labelYOUNG
# the image name  22617.jpg and labelOLD
# the image name  11177.jpg and labelYOUNG
# the image name  2462.jpg and labelMIDDLE
# the image name  24116.jpg and labelMIDDLE
# the image name  17689.jpg and labelMIDDLE
# the image name  728.jpg and labelMIDDLE
# the image name  3003.jpg and labelMIDDLE
# the image name  14408.jpg and labelOLD
# the image name  6679.jpg and labelYOUNG
# the image name  15152.jpg and labelOLD
# the image name  24784.jpg and labelMIDDLE
# the image name  9970.jpg and labelYOUNG
# the image name  22550.jpg and labelOLD
# the image name  150.jpg and labelYOUNG
# the image name  7379.jpg and labelMIDDLE
# the image name  15387.jpg and labelMIDDLE
# the image name  2336.jpg and labelYOUNG
# the image name  9603.jpg and labelMIDDLE
# the image name  4025.jpg and labelOLD
# the image name  17696.jpg and labelMIDDLE
# the image name  17552.jpg and labelYOUNG
# the image name  5345.jpg and labelYOUNG
# the image name  19129.jpg and labelYOUNG
# the image name  14286.jpg and labelMIDDLE
# the image name  18235.jpg and labelMIDDLE
# the image name  20499.jpg and labelMIDDLE
# the image name  2728.jpg and labelYOUNG
# the image name  5171.jpg and labelMIDDLE
# the image name  25205.jpg and labelMIDDLE
# the image name  12263.jpg and labelMIDDLE
# the image name  25467.jpg and labelYOUNG
# the image name  2132.jpg and labelMIDDLE
# the image name  12677.jpg and labelYOUNG
# the image name  9527.jpg and labelMIDDLE
# the image name  19846.jpg and labelMIDDLE
# the image name  1943.jpg and labelOLD
# the image name  4639.jpg and labelMIDDLE
# the image name  20686.jpg and labelYOUNG
# the image name  2412.jpg and labelMIDDLE
# the image name  3512.jpg and labelMIDDLE
# the image name  22350.jpg and labelYOUNG
# the image name  2691.jpg and labelMIDDLE
# the image name  15224.jpg and labelMIDDLE
# the image name  14864.jpg and labelMIDDLE
# the image name  22930.jpg and labelYOUNG
# the image name  24050.jpg and labelMIDDLE
# the image name  7445.jpg and labelMIDDLE
# the image name  24888.jpg and labelOLD
# the image name  1031.jpg and labelMIDDLE
# the image name  22890.jpg and labelOLD
# the image name  11249.jpg and labelMIDDLE
# the image name  13593.jpg and labelYOUNG
# the image name  3631.jpg and labelMIDDLE
# the image name  15523.jpg and labelYOUNG
# the image name  20243.jpg and labelYOUNG
# the image name  11345.jpg and labelMIDDLE
# the image name  26340.jpg and labelMIDDLE
# the image name  1195.jpg and labelOLD
# the image name  17965.jpg and labelYOUNG
# the image name  26054.jpg and labelYOUNG
# the image name  16522.jpg and labelYOUNG
# the image name  18131.jpg and labelYOUNG
# the image name  20229.jpg and labelMIDDLE
# the image name  4204.jpg and labelOLD
# the image name  18855.jpg and labelMIDDLE
# the image name  18266.jpg and labelMIDDLE
# the image name  17075.jpg and labelOLD
# the image name  13846.jpg and labelYOUNG
# the image name  24302.jpg and labelMIDDLE
# the image name  12982.jpg and labelMIDDLE
# the image name  21288.jpg and labelMIDDLE
# the image name  8324.jpg and labelMIDDLE
# the image name  13890.jpg and labelMIDDLE
# the image name  8177.jpg and labelMIDDLE
# the image name  9669.jpg and labelYOUNG
# the image name  19842.jpg and labelOLD
# the image name  2675.jpg and labelMIDDLE
# the image name  26465.jpg and labelYOUNG
# the image name  5641.jpg and labelMIDDLE
# the image name  17843.jpg and labelYOUNG
# the image name  26070.jpg and labelMIDDLE
# the image name  6808.jpg and labelMIDDLE
# the image name  777.jpg and labelYOUNG
# the image name  7717.jpg and labelMIDDLE
# the image name  2225.jpg and labelYOUNG
# the image name  852.jpg and labelYOUNG
# the image name  12619.jpg and labelYOUNG
# the image name  5843.jpg and labelMIDDLE
# the image name  20147.jpg and labelOLD
# the image name  15364.jpg and labelMIDDLE
# the image name  5824.jpg and labelYOUNG
# the image name  5671.jpg and labelOLD
# the image name  24021.jpg and labelYOUNG
# the image name  18961.jpg and labelMIDDLE
# the image name  10757.jpg and labelMIDDLE
# the image name  18115.jpg and labelMIDDLE
# the image name  18305.jpg and labelMIDDLE
# the image name  20262.jpg and labelMIDDLE
# the image name  26028.jpg and labelMIDDLE
# the image name  12301.jpg and labelMIDDLE
# the image name  17881.jpg and labelYOUNG
# the image name  5397.jpg and labelOLD
# the image name  19323.jpg and labelMIDDLE
# the image name  24429.jpg and labelOLD
# the image name  17693.jpg and labelMIDDLE
# the image name  26195.jpg and labelMIDDLE
# the image name  8421.jpg and labelYOUNG
# the image name  4969.jpg and labelYOUNG
# the image name  11511.jpg and labelOLD
# the image name  12816.jpg and labelYOUNG
# the image name  19367.jpg and labelMIDDLE
# the image name  11841.jpg and labelYOUNG
# the image name  23894.jpg and labelMIDDLE
# the image name  26212.jpg and labelMIDDLE
# the image name  21423.jpg and labelMIDDLE
# the image name  21323.jpg and labelMIDDLE
# the image name  1002.jpg and labelMIDDLE
# the image name  10851.jpg and labelYOUNG
# the image name  19502.jpg and labelMIDDLE
# the image name  1279.jpg and labelMIDDLE
# the image name  23028.jpg and labelMIDDLE
# the image name  20782.jpg and labelMIDDLE
# the image name  10868.jpg and labelMIDDLE
# the image name  10214.jpg and labelMIDDLE
# the image name  7049.jpg and labelYOUNG
# the image name  6231.jpg and labelMIDDLE
# the image name  2513.jpg and labelOLD
# the image name  10811.jpg and labelMIDDLE
# the image name  16073.jpg and labelMIDDLE
# the image name  23594.jpg and labelOLD
# the image name  75.jpg and labelMIDDLE
# the image name  4230.jpg and labelMIDDLE
# the image name  3243.jpg and labelMIDDLE
# the image name  23116.jpg and labelOLD
# the image name  21926.jpg and labelMIDDLE
# the image name  25269.jpg and labelMIDDLE
# the image name  9977.jpg and labelMIDDLE
# the image name  22356.jpg and labelYOUNG
# the image name  12817.jpg and labelYOUNG
# the image name  24633.jpg and labelMIDDLE
# the image name  21159.jpg and labelMIDDLE
# the image name  1498.jpg and labelMIDDLE
# the image name  14950.jpg and labelOLD
# the image name  4333.jpg and labelMIDDLE
# the image name  25106.jpg and labelYOUNG
# the image name  2309.jpg and labelOLD
# the image name  17297.jpg and labelMIDDLE
# the image name  24832.jpg and labelYOUNG
# the image name  1327.jpg and labelYOUNG
# the image name  22246.jpg and labelYOUNG
# the image name  23677.jpg and labelOLD
# the image name  6129.jpg and labelMIDDLE
# the image name  7922.jpg and labelYOUNG
# the image name  11819.jpg and labelMIDDLE
# the image name  25396.jpg and labelMIDDLE
# the image name  17186.jpg and labelMIDDLE
# the image name  24952.jpg and labelMIDDLE
# the image name  21448.jpg and labelYOUNG
# the image name  14936.jpg and labelYOUNG
# the image name  6958.jpg and labelMIDDLE
# the image name  19636.jpg and labelMIDDLE
# the image name  24280.jpg and labelYOUNG
# the image name  793.jpg and labelYOUNG
# the image name  15356.jpg and labelMIDDLE
# the image name  4059.jpg and labelOLD
# the image name  7743.jpg and labelMIDDLE
# the image name  12422.jpg and labelMIDDLE
# the image name  10631.jpg and labelOLD
# the image name  23986.jpg and labelYOUNG
# the image name  15245.jpg and labelOLD
# the image name  23668.jpg and labelMIDDLE
# the image name  1577.jpg and labelOLD
# the image name  22433.jpg and labelMIDDLE
# the image name  12358.jpg and labelYOUNG
# the image name  14264.jpg and labelMIDDLE
# the image name  20072.jpg and labelYOUNG
# the image name  24826.jpg and labelYOUNG
# the image name  14441.jpg and labelYOUNG
# the image name  22953.jpg and labelYOUNG
# the image name  22844.jpg and labelOLD
# the image name  22016.jpg and labelYOUNG
# the image name  2251.jpg and labelMIDDLE
# the image name  1802.jpg and labelMIDDLE
# the image name  24198.jpg and labelMIDDLE
# the image name  14397.jpg and labelMIDDLE
# the image name  11858.jpg and labelMIDDLE
# the image name  11785.jpg and labelMIDDLE
# the image name  12973.jpg and labelMIDDLE
# the image name  6191.jpg and labelMIDDLE
# the image name  17739.jpg and labelMIDDLE
# the image name  8469.jpg and labelMIDDLE
# the image name  1543.jpg and labelMIDDLE
# the image name  10667.jpg and labelMIDDLE
# the image name  7632.jpg and labelMIDDLE
# the image name  1794.jpg and labelOLD
# the image name  3250.jpg and labelYOUNG
# the image name  3108.jpg and labelYOUNG
# the image name  23546.jpg and labelYOUNG
# the image name  5312.jpg and labelMIDDLE
# the image name  4272.jpg and labelYOUNG
# the image name  18184.jpg and labelYOUNG
# the image name  17152.jpg and labelMIDDLE
# the image name  19391.jpg and labelMIDDLE
# the image name  10101.jpg and labelYOUNG
# the image name  13988.jpg and labelYOUNG
# the image name  17429.jpg and labelYOUNG
# the image name  21877.jpg and labelOLD
# the image name  12839.jpg and labelMIDDLE
# the image name  19310.jpg and labelYOUNG
# the image name  5152.jpg and labelYOUNG
# the image name  13880.jpg and labelYOUNG
# the image name  4335.jpg and labelMIDDLE
# the image name  22094.jpg and labelYOUNG
# the image name  1009.jpg and labelYOUNG
# the image name  6716.jpg and labelMIDDLE
# the image name  21694.jpg and labelMIDDLE
# the image name  8502.jpg and labelMIDDLE
# the image name  1445.jpg and labelYOUNG
# the image name  26450.jpg and labelMIDDLE
# the image name  25002.jpg and labelMIDDLE
# the image name  1657.jpg and labelOLD
# the image name  22226.jpg and labelOLD
# the image name  1864.jpg and labelYOUNG
# the image name  2662.jpg and labelMIDDLE
# the image name  15129.jpg and labelMIDDLE
# the image name  18602.jpg and labelMIDDLE
# the image name  26315.jpg and labelMIDDLE
# the image name  12725.jpg and labelYOUNG
# the image name  25960.jpg and labelMIDDLE
# the image name  14673.jpg and labelMIDDLE
# the image name  12282.jpg and labelOLD
# the image name  17861.jpg and labelMIDDLE
# the image name  15847.jpg and labelMIDDLE
# the image name  2574.jpg and labelYOUNG
# the image name  9657.jpg and labelMIDDLE
# the image name  19785.jpg and labelMIDDLE
# the image name  2678.jpg and labelYOUNG
# the image name  22923.jpg and labelYOUNG
# the image name  1141.jpg and labelMIDDLE
# the image name  25604.jpg and labelOLD
# the image name  13766.jpg and labelMIDDLE
# the image name  21429.jpg and labelMIDDLE
# the image name  12024.jpg and labelMIDDLE
# the image name  7402.jpg and labelYOUNG
# the image name  20975.jpg and labelYOUNG
# the image name  9331.jpg and labelOLD
# the image name  462.jpg and labelYOUNG
# the image name  8203.jpg and labelMIDDLE
# the image name  14258.jpg and labelMIDDLE
# the image name  7062.jpg and labelYOUNG
# the image name  18802.jpg and labelMIDDLE
# the image name  19897.jpg and labelMIDDLE
# the image name  16897.jpg and labelMIDDLE
# the image name  7553.jpg and labelMIDDLE
# the image name  13594.jpg and labelYOUNG
# the image name  10156.jpg and labelMIDDLE
# the image name  1048.jpg and labelMIDDLE
# the image name  19849.jpg and labelYOUNG
# the image name  9354.jpg and labelYOUNG
# the image name  22689.jpg and labelMIDDLE
# the image name  2385.jpg and labelMIDDLE
# the image name  24210.jpg and labelYOUNG
# the image name  23747.jpg and labelYOUNG
# the image name  9476.jpg and labelYOUNG
# the image name  976.jpg and labelMIDDLE
# the image name  26485.jpg and labelMIDDLE
# the image name  13794.jpg and labelOLD
# the image name  22391.jpg and labelMIDDLE
# the image name  5102.jpg and labelOLD
# the image name  25745.jpg and labelMIDDLE
# the image name  26027.jpg and labelOLD
# the image name  11441.jpg and labelYOUNG
# the image name  16395.jpg and labelMIDDLE
# the image name  11128.jpg and labelMIDDLE
# the image name  9659.jpg and labelMIDDLE
# the image name  18709.jpg and labelMIDDLE
# the image name  2296.jpg and labelMIDDLE
# the image name  7540.jpg and labelOLD
# the image name  24889.jpg and labelOLD
# the image name  20476.jpg and labelYOUNG
# the image name  14522.jpg and labelYOUNG
# the image name  12865.jpg and labelOLD
# the image name  9239.jpg and labelMIDDLE
# the image name  1260.jpg and labelOLD
# the image name  14067.jpg and labelYOUNG
# the image name  7724.jpg and labelMIDDLE
# the image name  25069.jpg and labelMIDDLE
# the image name  16587.jpg and labelMIDDLE
# the image name  16419.jpg and labelYOUNG
# the image name  16905.jpg and labelMIDDLE
# the image name  13319.jpg and labelMIDDLE
# the image name  14833.jpg and labelYOUNG
# the image name  24224.jpg and labelMIDDLE
# the image name  22506.jpg and labelMIDDLE
# the image name  2372.jpg and labelOLD
# the image name  11601.jpg and labelOLD
# the image name  4703.jpg and labelMIDDLE
# the image name  12549.jpg and labelYOUNG
# the image name  95.jpg and labelOLD
# the image name  10473.jpg and labelYOUNG
# the image name  4507.jpg and labelMIDDLE
# the image name  23183.jpg and labelYOUNG
# the image name  24278.jpg and labelOLD
# the image name  16191.jpg and labelYOUNG
# the image name  24956.jpg and labelMIDDLE
# the image name  8957.jpg and labelMIDDLE
# the image name  1030.jpg and labelMIDDLE
# the image name  14883.jpg and labelYOUNG
# the image name  13998.jpg and labelOLD
# the image name  7401.jpg and labelMIDDLE
# the image name  21727.jpg and labelYOUNG
# the image name  24312.jpg and labelMIDDLE
# the image name  5833.jpg and labelMIDDLE
# the image name  21178.jpg and labelMIDDLE
# the image name  10934.jpg and labelMIDDLE
# the image name  11275.jpg and labelMIDDLE
# the image name  2573.jpg and labelMIDDLE
# the image name  12302.jpg and labelMIDDLE
# the image name  21461.jpg and labelMIDDLE
# the image name  15647.jpg and labelYOUNG
# the image name  16943.jpg and labelOLD
# the image name  23982.jpg and labelMIDDLE
# the image name  24025.jpg and labelMIDDLE
# the image name  4171.jpg and labelMIDDLE
# the image name  1762.jpg and labelYOUNG
# the image name  3105.jpg and labelYOUNG
# the image name  25201.jpg and labelMIDDLE
# the image name  2138.jpg and labelMIDDLE
# the image name  1565.jpg and labelYOUNG
# the image name  11183.jpg and labelMIDDLE
# the image name  13258.jpg and labelYOUNG
# the image name  21428.jpg and labelYOUNG
# the image name  23105.jpg and labelYOUNG
# the image name  8432.jpg and labelYOUNG
# the image name  10907.jpg and labelMIDDLE
# the image name  1771.jpg and labelOLD
# the image name  17490.jpg and labelMIDDLE
# the image name  1709.jpg and labelYOUNG
# the image name  12810.jpg and labelMIDDLE
# the image name  1218.jpg and labelMIDDLE
# the image name  7415.jpg and labelMIDDLE
# the image name  22068.jpg and labelYOUNG
# the image name  8429.jpg and labelMIDDLE
# the image name  15851.jpg and labelMIDDLE
# the image name  1291.jpg and labelYOUNG
# the image name  11898.jpg and labelMIDDLE
# the image name  12868.jpg and labelOLD
# the image name  21699.jpg and labelMIDDLE
# the image name  23633.jpg and labelMIDDLE
# the image name  8858.jpg and labelMIDDLE
# the image name  8793.jpg and labelYOUNG
# the image name  12922.jpg and labelMIDDLE
# the image name  25684.jpg and labelMIDDLE
# the image name  14061.jpg and labelYOUNG
# the image name  23733.jpg and labelMIDDLE
# the image name  6335.jpg and labelMIDDLE
# the image name  9692.jpg and labelYOUNG
# the image name  25859.jpg and labelMIDDLE
# the image name  20123.jpg and labelYOUNG
# the image name  9320.jpg and labelMIDDLE
# the image name  5270.jpg and labelMIDDLE
# the image name  3612.jpg and labelMIDDLE
# the image name  13823.jpg and labelYOUNG
# the image name  4814.jpg and labelYOUNG
# the image name  3747.jpg and labelMIDDLE
# the image name  6195.jpg and labelMIDDLE
# the image name  20959.jpg and labelMIDDLE
# the image name  1571.jpg and labelOLD
# the image name  10810.jpg and labelOLD
# the image name  10584.jpg and labelMIDDLE
# the image name  4933.jpg and labelMIDDLE
# the image name  2599.jpg and labelYOUNG
# the image name  945.jpg and labelYOUNG
# the image name  12950.jpg and labelMIDDLE
# the image name  2395.jpg and labelOLD
# the image name  15562.jpg and labelYOUNG
# the image name  757.jpg and labelMIDDLE
# the image name  20638.jpg and labelYOUNG
# the image name  24169.jpg and labelYOUNG
# the image name  22545.jpg and labelYOUNG
# the image name  10799.jpg and labelMIDDLE
# the image name  16711.jpg and labelMIDDLE
# the image name  17151.jpg and labelMIDDLE
# the image name  7657.jpg and labelMIDDLE
# the image name  14783.jpg and labelMIDDLE
# the image name  23548.jpg and labelOLD
# the image name  17181.jpg and labelMIDDLE
# the image name  3673.jpg and labelMIDDLE
# the image name  12030.jpg and labelMIDDLE
# the image name  19919.jpg and labelOLD
# the image name  22991.jpg and labelMIDDLE
# the image name  15861.jpg and labelOLD
# the image name  8437.jpg and labelYOUNG
# the image name  9473.jpg and labelYOUNG
# the image name  15609.jpg and labelMIDDLE
# the image name  6234.jpg and labelMIDDLE
# the image name  453.jpg and labelMIDDLE
# the image name  8522.jpg and labelMIDDLE
# the image name  11424.jpg and labelMIDDLE
# the image name  17672.jpg and labelOLD
# the image name  8767.jpg and labelYOUNG
# the image name  7345.jpg and labelOLD
# the image name  20500.jpg and labelMIDDLE
# the image name  16194.jpg and labelOLD
# the image name  17485.jpg and labelMIDDLE
# the image name  6884.jpg and labelOLD
# the image name  22468.jpg and labelYOUNG
# the image name  3258.jpg and labelMIDDLE
# the image name  18815.jpg and labelYOUNG
# the image name  9055.jpg and labelMIDDLE
# the image name  18690.jpg and labelMIDDLE
# the image name  4451.jpg and labelMIDDLE
# the image name  15704.jpg and labelMIDDLE
# the image name  10622.jpg and labelMIDDLE
# the image name  10167.jpg and labelMIDDLE
# the image name  8567.jpg and labelOLD
# the image name  13612.jpg and labelYOUNG
# the image name  2802.jpg and labelOLD
# the image name  24193.jpg and labelOLD
# the image name  24877.jpg and labelMIDDLE
# the image name  15875.jpg and labelOLD
# the image name  23970.jpg and labelMIDDLE
# the image name  11505.jpg and labelOLD
# the image name  26483.jpg and labelMIDDLE
# the image name  8721.jpg and labelMIDDLE
# the image name  191.jpg and labelMIDDLE
# the image name  23650.jpg and labelMIDDLE
# the image name  24596.jpg and labelMIDDLE
# the image name  18139.jpg and labelYOUNG
# the image name  22393.jpg and labelYOUNG
# the image name  12437.jpg and labelMIDDLE
# the image name  13199.jpg and labelMIDDLE
# the image name  19786.jpg and labelMIDDLE
# the image name  16234.jpg and labelMIDDLE
# the image name  17919.jpg and labelYOUNG
# the image name  5024.jpg and labelMIDDLE
# the image name  9697.jpg and labelMIDDLE
# the image name  7968.jpg and labelYOUNG
# the image name  3149.jpg and labelMIDDLE
# the image name  23709.jpg and labelMIDDLE
# the image name  1849.jpg and labelYOUNG
# the image name  13827.jpg and labelMIDDLE
# the image name  16996.jpg and labelYOUNG
# the image name  13721.jpg and labelYOUNG
# the image name  68.jpg and labelMIDDLE
# the image name  5228.jpg and labelYOUNG
# the image name  20385.jpg and labelYOUNG
# the image name  18021.jpg and labelOLD
# the image name  22598.jpg and labelOLD
# the image name  8219.jpg and labelYOUNG
# the image name  9420.jpg and labelYOUNG
# the image name  24506.jpg and labelYOUNG
# the image name  978.jpg and labelMIDDLE
# the image name  6272.jpg and labelYOUNG
# the image name  21549.jpg and labelYOUNG
# the image name  12746.jpg and labelYOUNG
# the image name  13694.jpg and labelMIDDLE
# the image name  1059.jpg and labelYOUNG
# the image name  716.jpg and labelYOUNG
# the image name  14798.jpg and labelMIDDLE
# the image name  14635.jpg and labelMIDDLE
# the image name  8649.jpg and labelYOUNG
# the image name  23037.jpg and labelOLD
# the image name  19681.jpg and labelMIDDLE
# the image name  24175.jpg and labelMIDDLE
# the image name  15484.jpg and labelMIDDLE
# the image name  14090.jpg and labelYOUNG
# the image name  25094.jpg and labelMIDDLE
# the image name  3783.jpg and labelMIDDLE
# the image name  20356.jpg and labelMIDDLE
# the image name  14620.jpg and labelMIDDLE
# the image name  6588.jpg and labelYOUNG
# the image name  6609.jpg and labelYOUNG
# the image name  24760.jpg and labelYOUNG
# the image name  14105.jpg and labelYOUNG
# the image name  21920.jpg and labelMIDDLE
# the image name  20881.jpg and labelMIDDLE
# the image name  2303.jpg and labelMIDDLE
# the image name  14341.jpg and labelMIDDLE
# the image name  26454.jpg and labelYOUNG
# the image name  20350.jpg and labelYOUNG
# the image name  16154.jpg and labelOLD
# the image name  5911.jpg and labelMIDDLE
# the image name  13226.jpg and labelYOUNG
# the image name  22381.jpg and labelMIDDLE
# the image name  6841.jpg and labelMIDDLE
# the image name  20867.jpg and labelYOUNG
# the image name  601.jpg and labelYOUNG
# the image name  16406.jpg and labelMIDDLE
# the image name  20811.jpg and labelYOUNG
# the image name  4823.jpg and labelMIDDLE
# the image name  12033.jpg and labelYOUNG
# the image name  5859.jpg and labelYOUNG
# the image name  17169.jpg and labelMIDDLE
# the image name  6691.jpg and labelOLD
# the image name  537.jpg and labelMIDDLE
# the image name  26003.jpg and labelMIDDLE
# the image name  5069.jpg and labelMIDDLE
# the image name  1330.jpg and labelMIDDLE
# the image name  23418.jpg and labelMIDDLE
# the image name  361.jpg and labelOLD
# the image name  18517.jpg and labelMIDDLE
# the image name  17498.jpg and labelYOUNG
# the image name  14856.jpg and labelMIDDLE
# the image name  22929.jpg and labelMIDDLE
# the image name  12187.jpg and labelMIDDLE
# the image name  7679.jpg and labelMIDDLE
# the image name  16164.jpg and labelYOUNG
# the image name  9642.jpg and labelMIDDLE
# the image name  16748.jpg and labelYOUNG
# the image name  21761.jpg and labelMIDDLE
# the image name  17493.jpg and labelMIDDLE
# the image name  6629.jpg and labelYOUNG
# the image name  17110.jpg and labelMIDDLE
# the image name  798.jpg and labelMIDDLE
# the image name  11142.jpg and labelYOUNG
# the image name  25640.jpg and labelOLD
# the image name  7810.jpg and labelMIDDLE
# the image name  8993.jpg and labelYOUNG
# the image name  16723.jpg and labelMIDDLE
# the image name  7633.jpg and labelOLD
# the image name  4144.jpg and labelMIDDLE
# the image name  5242.jpg and labelOLD
# the image name  19168.jpg and labelMIDDLE
# the image name  21644.jpg and labelMIDDLE
# the image name  8831.jpg and labelMIDDLE
# the image name  26187.jpg and labelOLD
# the image name  5704.jpg and labelYOUNG
# the image name  15515.jpg and labelMIDDLE
# the image name  18480.jpg and labelMIDDLE
# the image name  11697.jpg and labelYOUNG
# the image name  2282.jpg and labelYOUNG
# the image name  22239.jpg and labelYOUNG
# the image name  14986.jpg and labelYOUNG
# the image name  23604.jpg and labelMIDDLE
# the image name  14869.jpg and labelMIDDLE
# the image name  5246.jpg and labelMIDDLE
# the image name  19727.jpg and labelMIDDLE
# the image name  16676.jpg and labelMIDDLE
# the image name  17711.jpg and labelMIDDLE
# the image name  11397.jpg and labelOLD
# the image name  16969.jpg and labelYOUNG
# the image name  2558.jpg and labelMIDDLE
# the image name  18931.jpg and labelMIDDLE
# the image name  17947.jpg and labelMIDDLE
# the image name  19409.jpg and labelMIDDLE
# the image name  21690.jpg and labelYOUNG
# the image name  14401.jpg and labelMIDDLE
# the image name  8140.jpg and labelOLD
# the image name  770.jpg and labelOLD
# the image name  4812.jpg and labelYOUNG
# the image name  23372.jpg and labelMIDDLE
# the image name  11078.jpg and labelOLD
# the image name  18606.jpg and labelMIDDLE
# the image name  15904.jpg and labelYOUNG
# the image name  16242.jpg and labelMIDDLE
# the image name  14278.jpg and labelMIDDLE
# the image name  25163.jpg and labelYOUNG
# the image name  22521.jpg and labelMIDDLE
# the image name  23118.jpg and labelYOUNG
# the image name  20202.jpg and labelYOUNG
# the image name  9719.jpg and labelYOUNG
# the image name  10469.jpg and labelYOUNG
# the image name  20893.jpg and labelYOUNG
# the image name  26463.jpg and labelYOUNG
# the image name  16345.jpg and labelOLD
# the image name  2898.jpg and labelYOUNG
# the image name  14404.jpg and labelMIDDLE
# the image name  19570.jpg and labelMIDDLE
# the image name  630.jpg and labelMIDDLE
# the image name  15437.jpg and labelYOUNG
# the image name  26350.jpg and labelMIDDLE
# the image name  8498.jpg and labelMIDDLE
# the image name  13456.jpg and labelMIDDLE
# the image name  2712.jpg and labelMIDDLE
# the image name  882.jpg and labelMIDDLE
# the image name  19021.jpg and labelMIDDLE
# the image name  17525.jpg and labelYOUNG
# the image name  25003.jpg and labelMIDDLE
# the image name  26211.jpg and labelMIDDLE
# the image name  15231.jpg and labelMIDDLE
# the image name  20553.jpg and labelYOUNG
# the image name  15856.jpg and labelMIDDLE
# the image name  14928.jpg and labelYOUNG
# the image name  19416.jpg and labelMIDDLE
# the image name  15828.jpg and labelOLD
# the image name  18532.jpg and labelOLD
# the image name  20156.jpg and labelMIDDLE
# the image name  14871.jpg and labelYOUNG
# the image name  11638.jpg and labelYOUNG
# the image name  10737.jpg and labelYOUNG
# the image name  11570.jpg and labelYOUNG
# the image name  1237.jpg and labelMIDDLE
# the image name  23890.jpg and labelMIDDLE
# the image name  9572.jpg and labelMIDDLE
# the image name  5572.jpg and labelYOUNG
# the image name  14623.jpg and labelYOUNG
# the image name  6024.jpg and labelMIDDLE
# the image name  25055.jpg and labelYOUNG
# the image name  22168.jpg and labelMIDDLE
# the image name  6479.jpg and labelMIDDLE
# the image name  20036.jpg and labelOLD
# the image name  9647.jpg and labelMIDDLE
# the image name  20278.jpg and labelMIDDLE
# the image name  18117.jpg and labelMIDDLE
# the image name  16346.jpg and labelYOUNG
# the image name  24061.jpg and labelMIDDLE
# the image name  3810.jpg and labelMIDDLE
# the image name  14555.jpg and labelMIDDLE
# the image name  10923.jpg and labelYOUNG
# the image name  15933.jpg and labelMIDDLE
# the image name  444.jpg and labelYOUNG
# the image name  8447.jpg and labelMIDDLE
# the image name  3285.jpg and labelMIDDLE
# the image name  22669.jpg and labelMIDDLE
# the image name  15300.jpg and labelYOUNG
# the image name  6065.jpg and labelYOUNG
# the image name  4053.jpg and labelMIDDLE
# the image name  19591.jpg and labelOLD
# the image name  6971.jpg and labelYOUNG
# the image name  7086.jpg and labelMIDDLE
# the image name  353.jpg and labelMIDDLE
# the image name  3663.jpg and labelMIDDLE
# the image name  16731.jpg and labelYOUNG
# the image name  24118.jpg and labelMIDDLE
# the image name  9355.jpg and labelMIDDLE
# the image name  1873.jpg and labelMIDDLE
# the image name  21630.jpg and labelYOUNG
# the image name  3866.jpg and labelMIDDLE
# the image name  16486.jpg and labelMIDDLE
# the image name  25968.jpg and labelMIDDLE
# the image name  25351.jpg and labelMIDDLE
# the image name  19941.jpg and labelMIDDLE
# the image name  23222.jpg and labelYOUNG
# the image name  12265.jpg and labelYOUNG
# the image name  16999.jpg and labelYOUNG
# the image name  124.jpg and labelMIDDLE
# the image name  6319.jpg and labelYOUNG
# the image name  25861.jpg and labelMIDDLE
# the image name  15329.jpg and labelYOUNG
# the image name  17192.jpg and labelYOUNG
# the image name  25262.jpg and labelYOUNG
# the image name  9314.jpg and labelOLD
# the image name  6724.jpg and labelOLD
# the image name  6848.jpg and labelMIDDLE
# the image name  3915.jpg and labelMIDDLE
# the image name  272.jpg and labelYOUNG
# the image name  10211.jpg and labelYOUNG
# the image name  22557.jpg and labelMIDDLE
# the image name  20677.jpg and labelMIDDLE
# the image name  16413.jpg and labelMIDDLE
# the image name  14320.jpg and labelYOUNG
# the image name  25471.jpg and labelMIDDLE
# the image name  19840.jpg and labelYOUNG
# the image name  20926.jpg and labelYOUNG
# the image name  23231.jpg and labelMIDDLE
# the image name  12740.jpg and labelYOUNG
# the image name  17360.jpg and labelMIDDLE
# the image name  25268.jpg and labelMIDDLE
# the image name  4536.jpg and labelMIDDLE
# the image name  9578.jpg and labelMIDDLE
# the image name  13692.jpg and labelYOUNG
# the image name  16275.jpg and labelYOUNG
# the image name  4816.jpg and labelYOUNG
# the image name  8166.jpg and labelMIDDLE
# the image name  5289.jpg and labelYOUNG
# the image name  12942.jpg and labelMIDDLE
# the image name  12515.jpg and labelMIDDLE
# the image name  3509.jpg and labelYOUNG
# the image name  583.jpg and labelOLD
# the image name  10847.jpg and labelMIDDLE
# the image name  11738.jpg and labelMIDDLE
# the image name  14210.jpg and labelOLD
# the image name  16171.jpg and labelMIDDLE
# the image name  23501.jpg and labelMIDDLE
# the image name  25041.jpg and labelMIDDLE
# the image name  439.jpg and labelMIDDLE
# the image name  24395.jpg and labelYOUNG
# the image name  7429.jpg and labelMIDDLE
# the image name  7212.jpg and labelMIDDLE
# the image name  435.jpg and labelMIDDLE
# the image name  10172.jpg and labelMIDDLE
# the image name  6281.jpg and labelMIDDLE
# the image name  7725.jpg and labelYOUNG
# the image name  4593.jpg and labelYOUNG
# the image name  20030.jpg and labelOLD
# the image name  24250.jpg and labelMIDDLE
# the image name  22414.jpg and labelYOUNG
# the image name  211.jpg and labelMIDDLE
# the image name  7802.jpg and labelOLD
# the image name  13164.jpg and labelOLD
# the image name  23915.jpg and labelMIDDLE
# the image name  24645.jpg and labelOLD
# the image name  22420.jpg and labelMIDDLE
# the image name  4800.jpg and labelOLD
# the image name  3194.jpg and labelOLD
# the image name  3647.jpg and labelYOUNG
# the image name  25398.jpg and labelMIDDLE
# the image name  17481.jpg and labelMIDDLE
# the image name  9944.jpg and labelYOUNG
# the image name  7646.jpg and labelYOUNG
# the image name  19112.jpg and labelMIDDLE
# the image name  14719.jpg and labelMIDDLE
# the image name  18665.jpg and labelMIDDLE
# the image name  16174.jpg and labelYOUNG
# the image name  17292.jpg and labelMIDDLE
# the image name  16059.jpg and labelMIDDLE
# the image name  1382.jpg and labelMIDDLE
# the image name  1997.jpg and labelYOUNG
# the image name  17791.jpg and labelMIDDLE
# the image name  15490.jpg and labelYOUNG
# the image name  23730.jpg and labelMIDDLE
# the image name  18002.jpg and labelMIDDLE
# the image name  23643.jpg and labelMIDDLE
# the image name  1884.jpg and labelYOUNG
# the image name  155.jpg and labelYOUNG
# the image name  15076.jpg and labelYOUNG
# the image name  26063.jpg and labelMIDDLE
# the image name  5590.jpg and labelMIDDLE
# the image name  22151.jpg and labelOLD
# the image name  11900.jpg and labelMIDDLE
# the image name  20430.jpg and labelYOUNG
# the image name  10619.jpg and labelMIDDLE
# the image name  4193.jpg and labelMIDDLE
# the image name  18394.jpg and labelYOUNG
# the image name  10741.jpg and labelMIDDLE
# the image name  5921.jpg and labelMIDDLE
# the image name  22139.jpg and labelMIDDLE
# the image name  7404.jpg and labelMIDDLE
# the image name  3719.jpg and labelMIDDLE
# the image name  20708.jpg and labelYOUNG
# the image name  2822.jpg and labelOLD
# the image name  25977.jpg and labelMIDDLE
# the image name  241.jpg and labelMIDDLE
# the image name  26517.jpg and labelYOUNG
# the image name  15626.jpg and labelMIDDLE
# the image name  3145.jpg and labelMIDDLE
# the image name  24087.jpg and labelYOUNG
# the image name  12080.jpg and labelMIDDLE
# the image name  2652.jpg and labelYOUNG
# the image name  8955.jpg and labelOLD
# the image name  1906.jpg and labelMIDDLE
# the image name  6139.jpg and labelOLD
# the image name  2059.jpg and labelYOUNG
# the image name  11381.jpg and labelMIDDLE
# the image name  2319.jpg and labelOLD
# the image name  9592.jpg and labelMIDDLE
# the image name  6032.jpg and labelMIDDLE
# the image name  8254.jpg and labelOLD
# the image name  7322.jpg and labelMIDDLE
# the image name  13038.jpg and labelMIDDLE
# the image name  6859.jpg and labelYOUNG
# the image name  16449.jpg and labelYOUNG
# the image name  8690.jpg and labelYOUNG
# the image name  13950.jpg and labelMIDDLE
# the image name  6380.jpg and labelMIDDLE
# the image name  7246.jpg and labelMIDDLE
# the image name  1950.jpg and labelMIDDLE
# the image name  12252.jpg and labelYOUNG
# the image name  13611.jpg and labelMIDDLE
# the image name  887.jpg and labelMIDDLE
# the image name  153.jpg and labelMIDDLE
# the image name  18354.jpg and labelYOUNG
# the image name  6104.jpg and labelMIDDLE
# the image name  246.jpg and labelYOUNG
# the image name  12351.jpg and labelMIDDLE
# the image name  9702.jpg and labelYOUNG
# the image name  7800.jpg and labelYOUNG
# the image name  20737.jpg and labelMIDDLE
# the image name  14899.jpg and labelYOUNG
# the image name  7497.jpg and labelMIDDLE
# the image name  14937.jpg and labelOLD
# the image name  15181.jpg and labelYOUNG
# the image name  17589.jpg and labelMIDDLE
# the image name  8588.jpg and labelYOUNG
# the image name  9414.jpg and labelMIDDLE
# the image name  9197.jpg and labelOLD
# the image name  25804.jpg and labelMIDDLE
# the image name  13184.jpg and labelMIDDLE
# the image name  16513.jpg and labelYOUNG
# the image name  15174.jpg and labelMIDDLE
# the image name  9412.jpg and labelYOUNG
# the image name  20021.jpg and labelMIDDLE
# the image name  1118.jpg and labelMIDDLE
# the image name  24126.jpg and labelYOUNG
# the image name  6312.jpg and labelMIDDLE
# the image name  14812.jpg and labelYOUNG
# the image name  18089.jpg and labelMIDDLE
# the image name  12780.jpg and labelYOUNG
# the image name  25591.jpg and labelYOUNG
# the image name  12770.jpg and labelMIDDLE
# the image name  9145.jpg and labelMIDDLE
# the image name  22959.jpg and labelMIDDLE
# the image name  19299.jpg and labelOLD
# the image name  1703.jpg and labelMIDDLE
# the image name  10073.jpg and labelMIDDLE
# the image name  9045.jpg and labelYOUNG
# the image name  20067.jpg and labelYOUNG
# the image name  20763.jpg and labelOLD
# the image name  16639.jpg and labelYOUNG
# the image name  17802.jpg and labelMIDDLE
# the image name  4358.jpg and labelMIDDLE
# the image name  2205.jpg and labelYOUNG
# the image name  11796.jpg and labelMIDDLE
# the image name  14378.jpg and labelMIDDLE
# the image name  17376.jpg and labelYOUNG
# the image name  22434.jpg and labelMIDDLE
# the image name  5616.jpg and labelOLD
# the image name  15740.jpg and labelYOUNG
# the image name  11543.jpg and labelMIDDLE
# the image name  4117.jpg and labelMIDDLE
# the image name  1198.jpg and labelMIDDLE
# the image name  5077.jpg and labelMIDDLE
# the image name  14019.jpg and labelMIDDLE
# the image name  19054.jpg and labelOLD
# the image name  7623.jpg and labelYOUNG
# the image name  4379.jpg and labelYOUNG
# the image name  3795.jpg and labelYOUNG
# the image name  809.jpg and labelMIDDLE
# the image name  24574.jpg and labelMIDDLE
# the image name  22436.jpg and labelMIDDLE
# the image name  8367.jpg and labelYOUNG
# the image name  22573.jpg and labelMIDDLE
# the image name  648.jpg and labelYOUNG
# the image name  24906.jpg and labelMIDDLE
# the image name  18900.jpg and labelMIDDLE
# the image name  20337.jpg and labelMIDDLE
# the image name  14350.jpg and labelYOUNG
# the image name  5943.jpg and labelYOUNG
# the image name  13775.jpg and labelMIDDLE
# the image name  21558.jpg and labelMIDDLE
# the image name  16548.jpg and labelMIDDLE
# the image name  16137.jpg and labelOLD
# the image name  10457.jpg and labelMIDDLE
# the image name  19748.jpg and labelYOUNG
# the image name  18491.jpg and labelMIDDLE
# the image name  15943.jpg and labelYOUNG
# the image name  6278.jpg and labelMIDDLE
# the image name  12053.jpg and labelYOUNG
# the image name  11096.jpg and labelYOUNG
# the image name  20029.jpg and labelMIDDLE
# the image name  6978.jpg and labelYOUNG
# the image name  952.jpg and labelMIDDLE
# the image name  25713.jpg and labelMIDDLE
# the image name  19962.jpg and labelMIDDLE
# the image name  8111.jpg and labelMIDDLE
# the image name  17149.jpg and labelMIDDLE
# the image name  12552.jpg and labelMIDDLE
# the image name  19703.jpg and labelOLD
# the image name  4828.jpg and labelMIDDLE
# the image name  2455.jpg and labelMIDDLE
# the image name  18470.jpg and labelYOUNG
# the image name  7095.jpg and labelYOUNG
# the image name  18738.jpg and labelMIDDLE
# the image name  5647.jpg and labelOLD
# the image name  15682.jpg and labelMIDDLE
# the image name  8503.jpg and labelMIDDLE
# the image name  11974.jpg and labelMIDDLE
# the image name  8239.jpg and labelOLD
# the image name  10302.jpg and labelMIDDLE
# the image name  19321.jpg and labelMIDDLE
# the image name  12026.jpg and labelYOUNG
# the image name  984.jpg and labelMIDDLE
# the image name  24130.jpg and labelMIDDLE
# the image name  24199.jpg and labelMIDDLE
# the image name  13417.jpg and labelYOUNG
# the image name  7546.jpg and labelMIDDLE
# the image name  10245.jpg and labelOLD
# the image name  15074.jpg and labelMIDDLE
# the image name  1939.jpg and labelYOUNG
# the image name  10736.jpg and labelMIDDLE
# the image name  24985.jpg and labelMIDDLE
# the image name  26474.jpg and labelMIDDLE
# the image name  4124.jpg and labelYOUNG
# the image name  2067.jpg and labelYOUNG
# the image name  14795.jpg and labelMIDDLE
# the image name  6232.jpg and labelMIDDLE
# the image name  10570.jpg and labelMIDDLE
# the image name  23285.jpg and labelYOUNG
# the image name  15606.jpg and labelOLD
# the image name  16783.jpg and labelYOUNG
# the image name  8451.jpg and labelMIDDLE
# the image name  20212.jpg and labelOLD
# the image name  18812.jpg and labelYOUNG
# the image name  21959.jpg and labelMIDDLE
# the image name  10108.jpg and labelMIDDLE
# the image name  11651.jpg and labelYOUNG
# the image name  11835.jpg and labelMIDDLE
# the image name  7292.jpg and labelMIDDLE
# the image name  8549.jpg and labelMIDDLE
# the image name  20716.jpg and labelMIDDLE
# the image name  10726.jpg and labelYOUNG
# the image name  11480.jpg and labelMIDDLE
# the image name  6209.jpg and labelYOUNG
# the image name  13121.jpg and labelYOUNG
# the image name  5047.jpg and labelYOUNG
# the image name  20312.jpg and labelOLD
# the image name  21817.jpg and labelMIDDLE
# the image name  17623.jpg and labelYOUNG
# the image name  2231.jpg and labelYOUNG
# the image name  6437.jpg and labelOLD
# the image name  12503.jpg and labelOLD
# the image name  15661.jpg and labelMIDDLE
# the image name  883.jpg and labelMIDDLE
# the image name  3667.jpg and labelMIDDLE
# the image name  5061.jpg and labelYOUNG
# the image name  14570.jpg and labelYOUNG
# the image name  18132.jpg and labelYOUNG
# the image name  19137.jpg and labelMIDDLE
# the image name  1385.jpg and labelMIDDLE
# the image name  26120.jpg and labelMIDDLE
# the image name  17308.jpg and labelMIDDLE
# the image name  5441.jpg and labelMIDDLE
# the image name  20120.jpg and labelMIDDLE
# the image name  24844.jpg and labelYOUNG
# the image name  17357.jpg and labelMIDDLE
# the image name  26271.jpg and labelOLD
# the image name  25971.jpg and labelYOUNG
# the image name  8055.jpg and labelMIDDLE
# the image name  23710.jpg and labelMIDDLE
# the image name  22157.jpg and labelMIDDLE
# the image name  17925.jpg and labelOLD
# the image name  7060.jpg and labelYOUNG
# the image name  13537.jpg and labelOLD
# the image name  20615.jpg and labelOLD
# the image name  16608.jpg and labelMIDDLE
# the image name  4061.jpg and labelMIDDLE
# the image name  14836.jpg and labelMIDDLE
# the image name  5585.jpg and labelYOUNG
# the image name  6622.jpg and labelMIDDLE
# the image name  3482.jpg and labelMIDDLE
# the image name  14643.jpg and labelMIDDLE
# the image name  5951.jpg and labelYOUNG
# the image name  1045.jpg and labelMIDDLE
# the image name  8223.jpg and labelMIDDLE
# the image name  17092.jpg and labelMIDDLE
# the image name  11985.jpg and labelYOUNG
# the image name  25870.jpg and labelYOUNG
# the image name  19447.jpg and labelYOUNG
# the image name  7597.jpg and labelYOUNG
# the image name  5266.jpg and labelYOUNG
# the image name  7291.jpg and labelYOUNG
# the image name  7249.jpg and labelMIDDLE
# the image name  7954.jpg and labelMIDDLE
# the image name  21802.jpg and labelOLD
# the image name  18893.jpg and labelYOUNG
# the image name  13018.jpg and labelOLD
# the image name  15257.jpg and labelMIDDLE
# the image name  3213.jpg and labelMIDDLE
# the image name  19929.jpg and labelYOUNG
# the image name  20000.jpg and labelYOUNG
# the image name  8270.jpg and labelMIDDLE
# the image name  14427.jpg and labelYOUNG
# the image name  22124.jpg and labelMIDDLE
# the image name  11957.jpg and labelMIDDLE
# the image name  12946.jpg and labelMIDDLE
# the image name  8552.jpg and labelMIDDLE
# the image name  21017.jpg and labelMIDDLE
# the image name  11115.jpg and labelOLD
# the image name  9013.jpg and labelYOUNG
# the image name  2188.jpg and labelMIDDLE
# the image name  7667.jpg and labelYOUNG
# the image name  22641.jpg and labelMIDDLE
# the image name  24351.jpg and labelYOUNG
# the image name  15894.jpg and labelYOUNG
# the image name  3487.jpg and labelOLD
# the image name  14717.jpg and labelYOUNG
# the image name  3059.jpg and labelYOUNG
# the image name  14903.jpg and labelMIDDLE
# the image name  8001.jpg and labelYOUNG
# the image name  16801.jpg and labelYOUNG
# the image name  2862.jpg and labelYOUNG
# the image name  14168.jpg and labelMIDDLE
# the image name  17629.jpg and labelYOUNG
# the image name  14155.jpg and labelMIDDLE
# the image name  21768.jpg and labelMIDDLE
# the image name  17420.jpg and labelYOUNG
# the image name  7361.jpg and labelYOUNG
# the image name  16654.jpg and labelYOUNG
# the image name  24939.jpg and labelMIDDLE
# the image name  23613.jpg and labelOLD
# the image name  2039.jpg and labelYOUNG
# the image name  781.jpg and labelOLD
# the image name  18672.jpg and labelMIDDLE
# the image name  21650.jpg and labelMIDDLE
# the image name  11265.jpg and labelYOUNG
# the image name  23717.jpg and labelOLD
# the image name  19488.jpg and labelMIDDLE
# the image name  11009.jpg and labelMIDDLE
# the image name  17083.jpg and labelMIDDLE
# the image name  26250.jpg and labelMIDDLE
# the image name  8077.jpg and labelMIDDLE
# the image name  15777.jpg and labelYOUNG
# the image name  26513.jpg and labelMIDDLE
# the image name  18577.jpg and labelYOUNG
# the image name  16770.jpg and labelMIDDLE
# the image name  24725.jpg and labelOLD
# the image name  15789.jpg and labelMIDDLE
# the image name  14997.jpg and labelYOUNG
# the image name  21721.jpg and labelYOUNG
# the image name  12479.jpg and labelMIDDLE
# the image name  24709.jpg and labelOLD
# the image name  11311.jpg and labelOLD
# the image name  5098.jpg and labelMIDDLE
# the image name  20616.jpg and labelYOUNG
# the image name  2810.jpg and labelYOUNG
# the image name  4264.jpg and labelMIDDLE
# the image name  23092.jpg and labelYOUNG
# the image name  17662.jpg and labelMIDDLE
# the image name  2497.jpg and labelOLD
# the image name  22528.jpg and labelMIDDLE
# the image name  1136.jpg and labelOLD
# the image name  19658.jpg and labelYOUNG
# the image name  2070.jpg and labelOLD
# the image name  13973.jpg and labelYOUNG
# the image name  19346.jpg and labelOLD
# the image name  16815.jpg and labelMIDDLE
# the image name  13628.jpg and labelMIDDLE
# the image name  8713.jpg and labelYOUNG
# the image name  8028.jpg and labelMIDDLE
# the image name  9066.jpg and labelMIDDLE
# the image name  16739.jpg and labelYOUNG
# the image name  14771.jpg and labelYOUNG
# the image name  3573.jpg and labelMIDDLE
# the image name  9484.jpg and labelMIDDLE
# the image name  14287.jpg and labelYOUNG
# the image name  22251.jpg and labelMIDDLE
# the image name  21108.jpg and labelMIDDLE
# the image name  11099.jpg and labelMIDDLE
# the image name  20876.jpg and labelMIDDLE
# the image name  5309.jpg and labelMIDDLE
# the image name  2848.jpg and labelMIDDLE
# the image name  4622.jpg and labelYOUNG
# the image name  19891.jpg and labelMIDDLE
# the image name  6015.jpg and labelMIDDLE
# the image name  21302.jpg and labelYOUNG
# the image name  3947.jpg and labelYOUNG
# the image name  9200.jpg and labelOLD
# the image name  8742.jpg and labelYOUNG
# the image name  4008.jpg and labelYOUNG
# the image name  21160.jpg and labelYOUNG
# the image name  9258.jpg and labelYOUNG
# the image name  13709.jpg and labelOLD
# the image name  11195.jpg and labelMIDDLE
# the image name  24317.jpg and labelMIDDLE
# the image name  18670.jpg and labelOLD
# the image name  10255.jpg and labelMIDDLE
# the image name  15266.jpg and labelMIDDLE
# the image name  2045.jpg and labelMIDDLE
# the image name  891.jpg and labelMIDDLE
# the image name  5359.jpg and labelMIDDLE
# the image name  5950.jpg and labelMIDDLE
# the image name  9046.jpg and labelYOUNG
# the image name  4904.jpg and labelYOUNG
# the image name  8714.jpg and labelMIDDLE
# the image name  24237.jpg and labelYOUNG
# the image name  12616.jpg and labelMIDDLE
# the image name  8965.jpg and labelMIDDLE
# the image name  12627.jpg and labelYOUNG
# the image name  11678.jpg and labelYOUNG
# the image name  13179.jpg and labelMIDDLE
# the image name  18164.jpg and labelOLD
# the image name  5900.jpg and labelYOUNG
# the image name  20560.jpg and labelYOUNG
# the image name  13833.jpg and labelMIDDLE
# the image name  11207.jpg and labelMIDDLE
# the image name  15390.jpg and labelYOUNG
# the image name  22811.jpg and labelOLD
# the image name  6000.jpg and labelYOUNG
# the image name  21930.jpg and labelMIDDLE
# the image name  5126.jpg and labelYOUNG
# the image name  24492.jpg and labelMIDDLE
# the image name  18735.jpg and labelMIDDLE
# the image name  20839.jpg and labelMIDDLE
# the image name  11616.jpg and labelMIDDLE
# the image name  9154.jpg and labelMIDDLE
# the image name  12584.jpg and labelYOUNG
# the image name  1021.jpg and labelMIDDLE
# the image name  6478.jpg and labelMIDDLE
# the image name  14388.jpg and labelYOUNG
# the image name  14694.jpg and labelMIDDLE
# the image name  16458.jpg and labelYOUNG
# the image name  5190.jpg and labelOLD
# the image name  917.jpg and labelMIDDLE
# the image name  821.jpg and labelMIDDLE
# the image name  6199.jpg and labelMIDDLE
# the image name  13590.jpg and labelMIDDLE
# the image name  22675.jpg and labelYOUNG
# the image name  4499.jpg and labelOLD
# the image name  10452.jpg and labelMIDDLE
# the image name  2656.jpg and labelOLD
# the image name  11244.jpg and labelMIDDLE
# the image name  4488.jpg and labelMIDDLE
# the image name  4021.jpg and labelMIDDLE
# the image name  3357.jpg and labelYOUNG
# the image name  12667.jpg and labelYOUNG
# the image name  13173.jpg and labelYOUNG
# the image name  23112.jpg and labelMIDDLE
# the image name  16727.jpg and labelMIDDLE
# the image name  10511.jpg and labelMIDDLE
# the image name  22732.jpg and labelYOUNG
# the image name  7663.jpg and labelOLD
# the image name  5207.jpg and labelOLD
# the image name  24677.jpg and labelMIDDLE
# the image name  3456.jpg and labelMIDDLE
# the image name  5222.jpg and labelMIDDLE
# the image name  3814.jpg and labelMIDDLE
# the image name  1355.jpg and labelYOUNG
# the image name  17422.jpg and labelMIDDLE
# the image name  8273.jpg and labelYOUNG
# the image name  6457.jpg and labelYOUNG
# the image name  17028.jpg and labelOLD
# the image name  19491.jpg and labelYOUNG
# the image name  22196.jpg and labelYOUNG
# the image name  18326.jpg and labelMIDDLE
# the image name  739.jpg and labelMIDDLE
# the image name  13499.jpg and labelMIDDLE
# the image name  6365.jpg and labelYOUNG
# the image name  7625.jpg and labelMIDDLE
# the image name  6806.jpg and labelMIDDLE
# the image name  21268.jpg and labelMIDDLE
# the image name  17604.jpg and labelMIDDLE
# the image name  12998.jpg and labelMIDDLE
# the image name  23398.jpg and labelYOUNG
# the image name  2164.jpg and labelYOUNG
# the image name  3101.jpg and labelMIDDLE
# the image name  3436.jpg and labelOLD
# the image name  3883.jpg and labelYOUNG
# the image name  6404.jpg and labelYOUNG
# the image name  22577.jpg and labelMIDDLE
# the image name  14655.jpg and labelOLD
# the image name  19063.jpg and labelYOUNG
# the image name  808.jpg and labelYOUNG
# the image name  3090.jpg and labelMIDDLE
# the image name  9765.jpg and labelMIDDLE
# the image name  3577.jpg and labelMIDDLE
# the image name  14365.jpg and labelYOUNG
# the image name  9510.jpg and labelYOUNG
# the image name  16130.jpg and labelMIDDLE
# the image name  23004.jpg and labelOLD
# the image name  18730.jpg and labelYOUNG
# the image name  3244.jpg and labelYOUNG
# the image name  1805.jpg and labelMIDDLE
# the image name  6877.jpg and labelMIDDLE
# the image name  7337.jpg and labelMIDDLE
# the image name  15259.jpg and labelYOUNG
# the image name  19982.jpg and labelOLD
# the image name  17905.jpg and labelMIDDLE
# the image name  8198.jpg and labelMIDDLE
# the image name  2622.jpg and labelMIDDLE
# the image name  1359.jpg and labelYOUNG
# the image name  15640.jpg and labelMIDDLE
# the image name  586.jpg and labelMIDDLE
# the image name  22848.jpg and labelYOUNG
# the image name  20115.jpg and labelMIDDLE
# the image name  5436.jpg and labelMIDDLE
# the image name  10981.jpg and labelMIDDLE
# the image name  7866.jpg and labelMIDDLE
# the image name  23137.jpg and labelYOUNG
# the image name  16848.jpg and labelMIDDLE
# the image name  2829.jpg and labelYOUNG
# the image name  2115.jpg and labelMIDDLE
# the image name  24660.jpg and labelOLD
# the image name  23097.jpg and labelMIDDLE
# the image name  6248.jpg and labelOLD
# ...
# the image name  26189.jpg and labelMIDDLE
# the image name  20838.jpg and labelYOUNG
# the image name  5115.jpg and labelYOUNG
# the image name  25122.jpg and labelMIDDLE
# the image name  13483.jpg and labelMIDDLE
# the image name  14619.jpg and labelOLD
# the image name  23955.jpg and labelMIDDLE
# the image name  7194.jpg and labelOLD
# the image name  562.jpg and labelMIDDLE
# the image name  13163.jpg and labelOLD
# the image name  8603.jpg and labelMIDDLE
# the image name  1288.jpg and labelYOUNG
# the image name  17288.jpg and labelMIDDLE
# the image name  1351.jpg and labelYOUNG
# the image name  5049.jpg and labelMIDDLE
# the image name  5885.jpg and labelYOUNG
# the image name  1408.jpg and labelOLD
# the image name  3583.jpg and labelYOUNG
# the image name  22397.jpg and labelYOUNG
# the image name  21001.jpg and labelMIDDLE
# the image name  14180.jpg and labelMIDDLE
# the image name  12736.jpg and labelMIDDLE
# the image name  14983.jpg and labelMIDDLE
# the image name  24743.jpg and labelMIDDLE
# the image name  2463.jpg and labelMIDDLE
# the image name  14304.jpg and labelMIDDLE
# the image name  21748.jpg and labelMIDDLE
# the image name  15441.jpg and labelYOUNG
# the image name  17187.jpg and labelMIDDLE
# the image name  15872.jpg and labelYOUNG
# the image name  4576.jpg and labelMIDDLE
# the image name  2892.jpg and labelMIDDLE
# the image name  16777.jpg and labelYOUNG
# the image name  16809.jpg and labelYOUNG
# the image name  6011.jpg and labelMIDDLE
# the image name  19600.jpg and labelYOUNG
# the image name  12081.jpg and labelMIDDLE
# the image name  17996.jpg and labelMIDDLE
# the image name  6095.jpg and labelYOUNG
# the image name  2437.jpg and labelYOUNG
# the image name  14957.jpg and labelMIDDLE
# the image name  24564.jpg and labelYOUNG
# the image name  21119.jpg and labelMIDDLE
# the image name  14542.jpg and labelMIDDLE
# the image name  8904.jpg and labelYOUNG
# the image name  409.jpg and labelMIDDLE
# the image name  3582.jpg and labelMIDDLE
# the image name  22050.jpg and labelOLD
# the image name  756.jpg and labelMIDDLE
# the image name  12321.jpg and labelYOUNG
# the image name  9728.jpg and labelYOUNG
# the image name  13414.jpg and labelOLD
# the image name  5881.jpg and labelOLD
# the image name  5743.jpg and labelMIDDLE
# the image name  18443.jpg and labelYOUNG
# the image name  9386.jpg and labelYOUNG
# the image name  18187.jpg and labelMIDDLE
# the image name  25477.jpg and labelMIDDLE
# the image name  15848.jpg and labelMIDDLE
# the image name  4116.jpg and labelOLD
# the image name  78.jpg and labelMIDDLE
# the image name  22931.jpg and labelYOUNG
# the image name  14345.jpg and labelMIDDLE
# the image name  426.jpg and labelMIDDLE
# the image name  15272.jpg and labelMIDDLE
# the image name  17031.jpg and labelMIDDLE
# the image name  1270.jpg and labelYOUNG
# the image name  12472.jpg and labelYOUNG
# the image name  8326.jpg and labelYOUNG
# the image name  25764.jpg and labelMIDDLE
# the image name  12306.jpg and labelYOUNG
# the image name  12082.jpg and labelMIDDLE
# the image name  18535.jpg and labelMIDDLE
# the image name  6834.jpg and labelYOUNG
# the image name  20834.jpg and labelOLD
# the image name  17256.jpg and labelYOUNG
# the image name  6378.jpg and labelYOUNG
# the image name  10832.jpg and labelMIDDLE
# the image name  14136.jpg and labelMIDDLE
# the image name  25577.jpg and labelMIDDLE
# the image name  8530.jpg and labelMIDDLE
# the image name  6102.jpg and labelMIDDLE
# the image name  17751.jpg and labelMIDDLE
# the image name  16478.jpg and labelYOUNG
# the image name  15372.jpg and labelYOUNG
# the image name  13306.jpg and labelMIDDLE
# the image name  25175.jpg and labelYOUNG
# the image name  3422.jpg and labelMIDDLE
# the image name  14696.jpg and labelYOUNG
# the image name  17974.jpg and labelYOUNG
# the image name  12162.jpg and labelYOUNG
# the image name  17628.jpg and labelYOUNG
# the image name  25173.jpg and labelYOUNG
# the image name  2791.jpg and labelYOUNG
# the image name  21087.jpg and labelYOUNG
# the image name  4114.jpg and labelMIDDLE
# the image name  16202.jpg and labelYOUNG
# the image name  16635.jpg and labelOLD
# the image name  20346.jpg and labelMIDDLE
# the image name  25617.jpg and labelMIDDLE
# the image name  7689.jpg and labelMIDDLE
# the image name  7693.jpg and labelMIDDLE
# the image name  24011.jpg and labelMIDDLE
# the image name  3368.jpg and labelMIDDLE
# the image name  18359.jpg and labelYOUNG
# the image name  287.jpg and labelYOUNG
# the image name  21548.jpg and labelMIDDLE
# the image name  17176.jpg and labelMIDDLE
# the image name  21826.jpg and labelYOUNG
# the image name  4421.jpg and labelMIDDLE
# the image name  17276.jpg and labelMIDDLE
# the image name  25413.jpg and labelOLD
# the image name  7287.jpg and labelMIDDLE
# the image name  12696.jpg and labelYOUNG
# the image name  11027.jpg and labelMIDDLE
# the image name  4.jpg and labelMIDDLE
# the image name  19317.jpg and labelMIDDLE
# the image name  7071.jpg and labelMIDDLE
# the image name  17945.jpg and labelMIDDLE
# the image name  20762.jpg and labelYOUNG
# the image name  13750.jpg and labelYOUNG
# the image name  1584.jpg and labelMIDDLE
# the image name  918.jpg and labelMIDDLE
# the image name  20110.jpg and labelMIDDLE
# the image name  14685.jpg and labelYOUNG
# the image name  14959.jpg and labelMIDDLE
# the image name  17755.jpg and labelMIDDLE
# the image name  12527.jpg and labelYOUNG
# the image name  20407.jpg and labelOLD
# the image name  11451.jpg and labelMIDDLE
# the image name  20237.jpg and labelOLD
# the image name  10197.jpg and labelMIDDLE
# the image name  13284.jpg and labelYOUNG
# the image name  15204.jpg and labelYOUNG
# the image name  20612.jpg and labelMIDDLE
# the image name  4549.jpg and labelYOUNG
# the image name  22905.jpg and labelYOUNG
# the image name  19307.jpg and labelOLD
# the image name  10301.jpg and labelYOUNG
# the image name  17393.jpg and labelMIDDLE
# the image name  11547.jpg and labelOLD
# the image name  21370.jpg and labelYOUNG
# the image name  1411.jpg and labelYOUNG
# the image name  15034.jpg and labelMIDDLE
# the image name  3941.jpg and labelMIDDLE
# the image name  24339.jpg and labelYOUNG
# the image name  7097.jpg and labelYOUNG
# the image name  17444.jpg and labelMIDDLE
# the image name  6649.jpg and labelMIDDLE
# the image name  12855.jpg and labelMIDDLE
# the image name  9997.jpg and labelMIDDLE
# the image name  18090.jpg and labelOLD
# the image name  26323.jpg and labelYOUNG
# the image name  15506.jpg and labelYOUNG
# the image name  8765.jpg and labelYOUNG
# the image name  12923.jpg and labelMIDDLE
# the image name  9976.jpg and labelMIDDLE
# the image name  13826.jpg and labelOLD
# the image name  7618.jpg and labelOLD
# the image name  1488.jpg and labelOLD
# the image name  9243.jpg and labelMIDDLE
# the image name  10331.jpg and labelMIDDLE
# the image name  10346.jpg and labelMIDDLE
# the image name  18700.jpg and labelMIDDLE
# the image name  391.jpg and labelYOUNG
# the image name  14857.jpg and labelYOUNG
# the image name  9718.jpg and labelYOUNG
# the image name  14409.jpg and labelMIDDLE
# the image name  6667.jpg and labelMIDDLE
# the image name  24123.jpg and labelMIDDLE
# the image name  3156.jpg and labelMIDDLE
# the image name  7863.jpg and labelMIDDLE
# the image name  1034.jpg and labelYOUNG
# the image name  22331.jpg and labelYOUNG
# the image name  16854.jpg and labelMIDDLE
# the image name  12722.jpg and labelYOUNG
# the image name  3624.jpg and labelMIDDLE
# the image name  20561.jpg and labelYOUNG
# the image name  2535.jpg and labelMIDDLE
# the image name  16694.jpg and labelYOUNG
# the image name  2960.jpg and labelMIDDLE
# the image name  3970.jpg and labelOLD
# the image name  14545.jpg and labelYOUNG
# the image name  23877.jpg and labelMIDDLE
# the image name  1025.jpg and labelYOUNG
# the image name  5679.jpg and labelMIDDLE
# the image name  4836.jpg and labelMIDDLE
# the image name  1970.jpg and labelMIDDLE
# the image name  20511.jpg and labelMIDDLE
# the image name  11713.jpg and labelMIDDLE
# the image name  23516.jpg and labelYOUNG
# the image name  1008.jpg and labelYOUNG
# the image name  25749.jpg and labelOLD
# the image name  24349.jpg and labelMIDDLE
# the image name  14382.jpg and labelMIDDLE
# the image name  21062.jpg and labelYOUNG
# the image name  17029.jpg and labelMIDDLE
# the image name  21036.jpg and labelMIDDLE
# the image name  1514.jpg and labelYOUNG
# the image name  22566.jpg and labelYOUNG
# the image name  9746.jpg and labelMIDDLE
# the image name  11946.jpg and labelYOUNG
# the image name  21301.jpg and labelYOUNG
# the image name  18176.jpg and labelYOUNG
# the image name  23607.jpg and labelYOUNG
# the image name  4657.jpg and labelYOUNG
# the image name  8298.jpg and labelYOUNG
# the image name  1007.jpg and labelMIDDLE
# the image name  3239.jpg and labelYOUNG
# the image name  9265.jpg and labelMIDDLE
# the image name  20770.jpg and labelYOUNG
# the image name  16398.jpg and labelYOUNG
# the image name  19043.jpg and labelOLD
# the image name  16490.jpg and labelOLD
# the image name  16633.jpg and labelYOUNG
# the image name  9192.jpg and labelMIDDLE
# the image name  7126.jpg and labelMIDDLE
# the image name  18362.jpg and labelMIDDLE
# the image name  9614.jpg and labelMIDDLE
# the image name  4654.jpg and labelMIDDLE
# the image name  19795.jpg and labelMIDDLE
# the image name  15611.jpg and labelMIDDLE
# the image name  25671.jpg and labelMIDDLE
# the image name  14425.jpg and labelMIDDLE
# the image name  25466.jpg and labelYOUNG
# the image name  26135.jpg and labelMIDDLE
# the image name  3703.jpg and labelYOUNG
# the image name  7413.jpg and labelYOUNG
# the image name  23698.jpg and labelMIDDLE
# the image name  25677.jpg and labelMIDDLE
# the image name  18134.jpg and labelOLD
# the image name  8283.jpg and labelYOUNG
# the image name  24772.jpg and labelMIDDLE
# the image name  25740.jpg and labelYOUNG
# the image name  221.jpg and labelYOUNG
# the image name  18125.jpg and labelMIDDLE
# the image name  25392.jpg and labelOLD
# the image name  26089.jpg and labelYOUNG
# the image name  19836.jpg and labelOLD
# the image name  4466.jpg and labelMIDDLE
# the image name  16368.jpg and labelYOUNG
# the image name  6106.jpg and labelMIDDLE
# the image name  17892.jpg and labelMIDDLE
# the image name  12630.jpg and labelMIDDLE
# the image name  2941.jpg and labelOLD
# the image name  19801.jpg and labelOLD
# the image name  23610.jpg and labelMIDDLE
# the image name  4868.jpg and labelMIDDLE
# the image name  25553.jpg and labelYOUNG
# the image name  19651.jpg and labelMIDDLE
# the image name  589.jpg and labelYOUNG
# the image name  6507.jpg and labelYOUNG
# the image name  22652.jpg and labelYOUNG
# the image name  17959.jpg and labelOLD
# the image name  19213.jpg and labelYOUNG
# the image name  4721.jpg and labelOLD
# the image name  1595.jpg and labelMIDDLE
# the image name  5194.jpg and labelOLD
# the image name  18120.jpg and labelMIDDLE
# the image name  2959.jpg and labelMIDDLE
# the image name  6198.jpg and labelMIDDLE
# the image name  736.jpg and labelYOUNG
# the image name  21275.jpg and labelYOUNG
# the image name  20091.jpg and labelYOUNG
# the image name  13637.jpg and labelYOUNG
# the image name  21277.jpg and labelYOUNG
# the image name  18947.jpg and labelOLD
# the image name  8318.jpg and labelYOUNG
# the image name  25697.jpg and labelYOUNG
# the image name  10509.jpg and labelYOUNG
# the image name  3138.jpg and labelMIDDLE
# the image name  24370.jpg and labelMIDDLE
# the image name  24892.jpg and labelMIDDLE
# the image name  24378.jpg and labelYOUNG
# the image name  4458.jpg and labelYOUNG
# the image name  2058.jpg and labelYOUNG
# the image name  7117.jpg and labelYOUNG
# the image name  11861.jpg and labelMIDDLE
# the image name  16207.jpg and labelMIDDLE
# the image name  292.jpg and labelOLD
# the image name  5035.jpg and labelOLD
# the image name  60.jpg and labelMIDDLE
# the image name  4705.jpg and labelMIDDLE
# the image name  25810.jpg and labelMIDDLE
# the image name  19041.jpg and labelOLD
# the image name  3401.jpg and labelOLD
# the image name  18566.jpg and labelYOUNG
# the image name  26223.jpg and labelMIDDLE
# the image name  15807.jpg and labelMIDDLE
# the image name  19700.jpg and labelYOUNG
# the image name  5576.jpg and labelMIDDLE
# the image name  18605.jpg and labelOLD
# the image name  15575.jpg and labelOLD
# the image name  7989.jpg and labelMIDDLE
# the image name  11639.jpg and labelYOUNG
# the image name  13550.jpg and labelYOUNG
# the image name  250.jpg and labelYOUNG
# the image name  16538.jpg and labelYOUNG
# the image name  24251.jpg and labelMIDDLE
# the image name  531.jpg and labelYOUNG
# the image name  6131.jpg and labelMIDDLE
# the image name  12360.jpg and labelOLD
# the image name  11200.jpg and labelMIDDLE
# the image name  3043.jpg and labelMIDDLE
# the image name  5866.jpg and labelOLD
# the image name  3887.jpg and labelYOUNG
# the image name  9573.jpg and labelYOUNG
# the image name  21197.jpg and labelYOUNG
# the image name  7260.jpg and labelYOUNG
# the image name  24869.jpg and labelYOUNG
# the image name  6699.jpg and labelYOUNG
# the image name  1162.jpg and labelMIDDLE
# the image name  96.jpg and labelMIDDLE
# the image name  15456.jpg and labelMIDDLE
# the image name  4332.jpg and labelMIDDLE
# the image name  10262.jpg and labelMIDDLE
# the image name  3879.jpg and labelOLD
# the image name  7605.jpg and labelMIDDLE
# the image name  12767.jpg and labelMIDDLE
# the image name  1073.jpg and labelMIDDLE
# the image name  17673.jpg and labelOLD
# the image name  13182.jpg and labelYOUNG
# the image name  6448.jpg and labelMIDDLE
# the image name  18675.jpg and labelMIDDLE
# the image name  8570.jpg and labelMIDDLE
# the image name  21129.jpg and labelYOUNG
# the image name  14713.jpg and labelMIDDLE
# the image name  5513.jpg and labelMIDDLE
# the image name  21317.jpg and labelYOUNG
# the image name  16518.jpg and labelYOUNG
# the image name  23682.jpg and labelYOUNG
# the image name  4782.jpg and labelMIDDLE
# the image name  13197.jpg and labelMIDDLE
# the image name  24398.jpg and labelMIDDLE
# the image name  11449.jpg and labelMIDDLE
# the image name  12728.jpg and labelMIDDLE
# the image name  14349.jpg and labelMIDDLE
# the image name  11770.jpg and labelMIDDLE
# the image name  2060.jpg and labelMIDDLE
# the image name  22432.jpg and labelMIDDLE
# the image name  13065.jpg and labelYOUNG
# the image name  4603.jpg and labelYOUNG
# the image name  14654.jpg and labelYOUNG
# the image name  8745.jpg and labelMIDDLE
# the image name  22063.jpg and labelMIDDLE
# the image name  14562.jpg and labelMIDDLE
# the image name  11600.jpg and labelYOUNG
# the image name  7823.jpg and labelMIDDLE
# the image name  14080.jpg and labelMIDDLE
# the image name  14242.jpg and labelMIDDLE
# the image name  1331.jpg and labelOLD
# the image name  7897.jpg and labelMIDDLE
# the image name  5599.jpg and labelMIDDLE
# the image name  6630.jpg and labelMIDDLE
# the image name  6776.jpg and labelYOUNG
# the image name  3477.jpg and labelMIDDLE
# the image name  14456.jpg and labelMIDDLE
# the image name  4011.jpg and labelMIDDLE
# the image name  16067.jpg and labelMIDDLE
# the image name  22392.jpg and labelMIDDLE
# the image name  17818.jpg and labelMIDDLE
# the image name  11988.jpg and labelOLD
# the image name  9407.jpg and labelOLD
# the image name  25426.jpg and labelYOUNG
# the image name  16609.jpg and labelYOUNG
# the image name  18746.jpg and labelYOUNG
# the image name  25714.jpg and labelMIDDLE
# the image name  14939.jpg and labelMIDDLE
# the image name  10025.jpg and labelYOUNG
# the image name  6149.jpg and labelOLD
# the image name  9733.jpg and labelYOUNG
# the image name  22630.jpg and labelMIDDLE
# the image name  11803.jpg and labelMIDDLE
# the image name  10812.jpg and labelYOUNG
# the image name  7038.jpg and labelYOUNG
# the image name  3021.jpg and labelMIDDLE
# the image name  4727.jpg and labelYOUNG
# the image name  7979.jpg and labelMIDDLE
# the image name  26159.jpg and labelMIDDLE
# the image name  2040.jpg and labelMIDDLE
# the image name  25347.jpg and labelMIDDLE
# the image name  15100.jpg and labelYOUNG
# the image name  26182.jpg and labelMIDDLE
# the image name  742.jpg and labelOLD
# the image name  5318.jpg and labelMIDDLE
# the image name  25514.jpg and labelMIDDLE
# the image name  2482.jpg and labelMIDDLE
# the image name  20085.jpg and labelYOUNG
# the image name  19663.jpg and labelMIDDLE
# the image name  10132.jpg and labelMIDDLE
# the image name  9896.jpg and labelMIDDLE

# %%
# encode the labels using LabelEncoder
le = LabelEncoder()
le_labels = le.fit_transform(labels)

# get the shape of training labels
print ("[STATUS] training labels: {}".format(le_labels))
print ("[STATUS] training labels shape: {}".format(le_labels.shape))

# save features and labels
h5f_data = h5py.File("features.h5", 'w')
h5f_data.create_dataset('dataset_1', data=np.array(features))

h5f_label = h5py.File("label.h5", 'w')
h5f_label.create_dataset('dataset_1', data=np.array(le_labels))

h5f_data.close()
h5f_label.close()
# Out:
# [STATUS] training labels: [0 2 0 ... 0 0 0]
# [STATUS] training labels shape: (19906,)

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import numpy as np
import h5py
import os
import json
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from __future__ import print_function

# %%
# import features and labels
h5f_data  = h5py.File("features.h5", 'r')
h5f_label = h5py.File("label.h5", 'r')

features_string = h5f_data['dataset_1']
labels_string   = h5f_label['dataset_1']

features = np.array(features_string)
labels   = np.array(labels_string)

h5f_data.close()
h5f_label.close()

# verify the shape of features and labels
print ("[INFO] features shape: {}".format(features.shape))
print ("[INFO] labels shape: {}".format(labels.shape))

print ("[INFO] training started...")
# split the training and testing data
# Out:
# [INFO] features shape: (19906, 2048)
# [INFO] labels shape: (19906,)
# [INFO] training started...

# %%
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(features),
                                                                  np.array(labels),
                                                                  test_size=0.10,
                                                                  random_state=9)

print("[INFO] splitted train and test data...")
print("[INFO] train data  : {}".format(trainData.shape))
print("[INFO] test data   : {}".format(testData.shape))
print("[INFO] train labels: {}".format(trainLabels.shape))
print("[INFO] test labels : {}".format(testLabels.shape))
# Out:
# [INFO] splitted train and test data...
# [INFO] train data  : (17915, 2048)
# [INFO] test data   : (1991, 2048)
# [INFO] train labels: (17915,)
# [INFO] test labels : (1991,)

# %%
# Define model
from keras import models
from keras import layers
from keras import optimizers

# %%
epochs = 100

m# Create a model and add layers
model = Sequential()

# Add layers to our model
model.add(Flatten(input_shape=x_train.shape[1:]))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 525,315
# Trainable params: 525,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(optimizer=optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['acc'])

# %%
# Train model
history = model.fit(trainData, trainLabels,
                    epochs=epochs,
                    batch_size=32, 
                    validation_data=(testData, testLabels))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-769b77b043ac> in <module>()
#       2                     epochs=epochs,
#       3                     batch_size=32,
# ----> 4                     validation_data=(testData, testLabels))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     787                 feed_output_shapes,
#     788                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 789                 exception_prefix='target')
#     790
#     791             # Generate sample-wise weight values given the `sample_weight` and
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking target: expected dense_5 to have shape (3,) but got array with shape (1,)

# %%
# use logistic regression as the model
print("[INFO] creating model...")
model = LogisticRegression(random_state=9)
model.fit(trainData, trainLabels)

# use rank-1 and rank-5 predictions
print("[INFO] evaluating model...")
f = open("results.txt", "w")
rank_1 = 0
rank_5 = 0

# loop over test data
for (label, features) in zip(testLabels, testData):
	# predict the probability of each class label and
	# take the top-5 class labels
	predictions = model.predict_proba(np.atleast_2d(features))[0]
	predictions = np.argsort(predictions)[::-1][:5]

	# rank-1 prediction increment
	if label == predictions[0]:
		rank_1 += 1

	# rank-5 prediction increment
	if label in predictions:
		rank_5 += 1

# convert accuracies to percentages
rank_1 = (rank_1 / float(len(testLabels))) * 100
rank_5 = (rank_5 / float(len(testLabels))) * 100

# write the accuracies to file
f.write("Rank-1: {:.2f}%\n".format(rank_1))
f.write("Rank-5: {:.2f}%\n\n".format(rank_5))

# evaluate the model of test data
preds = model.predict(testData)

# write the classification report to file
f.write("{}\n".format(classification_report(testLabels, preds)))
f.close()

classifier_path="classifier.pickle"

# dump classifier to file
print("[INFO] saving model...")
pickle.dump(model, open(classifier_path, 'wb'))

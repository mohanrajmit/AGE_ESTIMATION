# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/AGE_ESTIMATION/blob/master/image_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image= cv2.imread("/content/1.png")
print(image.shape[0])
print(image.shape[1])
print(image.shape[2])
# Out:
# 881
# 1566
# 3

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
